# %% [markdown]
# # Exploratory Data Analysis

# %%
# Importing the libraries

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
# Define settings
import os

pd.set_option("display.precision", 3)
data_dir_path = os.getcwd() + '/dataverse_files/'

# %%
# Importing data
import pyreadr

croissance_et_climat_decadaires = pyreadr.read_r(data_dir_path + "croissance_et_climat_decadaires.rds" ).popitem()[1]
valorisation_annuelle = pyreadr.read_r(data_dir_path + "valorisation_annuelle.rds" ).popitem()[1]

# %% [markdown]
# ## Analysis of growths and decadal climates

# %%
df = croissance_et_climat_decadaires

# %%
df.head()
# Out:
#    ucs  safran     sol type_de_prairie  gestion   annee  decade   Tmin  \
# 0  789    2131  330343             tp3       20  1985.0     1.0 -2.289
# 1  789    2131  330343             tp3       20  1985.0     2.0 -5.740
# 2  789    2131  330343             tp3       20  1985.0     3.0  3.770
# 3  789    2131  330343             tp3       20  1985.0     4.0  8.230
# 4  789    2131  330343             tp3       20  1985.0     5.0 -1.380
#
#      Tmax    Tmoy  Rain      RG       im  croissance
# 0   3.178   0.444  12.3  28.912   43.573       0.032
# 1  -0.410  -3.075  19.5  33.793  104.188       0.000
# 2   9.130   6.450  36.8  24.751   82.772       0.046
# 3  12.450  10.340  14.4  32.975   26.195       0.075
# 4   2.520   0.570  25.3  48.912   88.562       0.015

# %%
print(df.shape)
print(df.columns)
print(df.info())
# Out:
# (18693829, 14)
# Index(['ucs', 'safran', 'sol', 'type_de_prairie', 'gestion', 'annee', 'decade',
#        'Tmin', 'Tmax', 'Tmoy', 'Rain', 'RG', 'im', 'croissance'],
#       dtype='object')
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18693829 entries, 0 to 18693828
# Data columns (total 14 columns):
#  #   Column           Dtype
# ---  ------           -----
#  0   ucs              int32
#  1   safran           int32
#  2   sol              int32
#  3   type_de_prairie  object
#  4   gestion          int32
#  5   annee            float64
#  6   decade           float64
#  7   Tmin             float64
#  8   Tmax             float64
#  9   Tmoy             float64
#  10  Rain             float64
#  11  RG               float64
#  12  im               float64
#  13  croissance       float64
# dtypes: float64(9), int32(4), object(1)
# memory usage: 1.7+ GB
# None

# %%
df.describe()
# Out:
#              ucs     safran        sol    gestion      annee     decade  \
# count  1.869e+07  1.869e+07  1.869e+07  1.869e+07  1.867e+07  1.867e+07
# mean   1.054e+03  2.523e+03  3.308e+05  1.362e+01  1.999e+03  1.900e+01
# std    2.229e+02  5.508e+02  6.531e+02  9.407e+00  8.626e+00  1.068e+01
# min    6.400e+02  1.309e+03  3.303e+05  1.000e+00  1.984e+03  1.000e+00
# 25%    8.880e+02  2.120e+03  3.306e+05  5.000e+00  1.991e+03  1.000e+01
# 50%    1.080e+03  2.497e+03  3.306e+05  1.500e+01  1.999e+03  1.900e+01
# 75%    1.222e+03  2.895e+03  3.306e+05  2.100e+01  2.006e+03  2.800e+01
# max    1.610e+03  3.886e+03  3.327e+05  3.000e+01  2.013e+03  3.700e+01
#
#             Tmin       Tmax       Tmoy       Rain         RG         im  \
# count  1.857e+07  1.857e+07  1.857e+07  1.857e+07  1.857e+07  1.857e+07
# mean   8.249e+00  1.464e+01  1.145e+01  2.578e+01  1.085e+02  4.798e+01
# std    4.365e+00  5.607e+00  4.893e+00  2.499e+01  6.581e+01  4.897e+01
# min   -8.760e+00 -5.380e+00 -7.020e+00  0.000e+00  7.170e+00  0.000e+00
# 25%    5.040e+00  1.043e+01  7.855e+00  6.800e+00  4.684e+01  1.144e+01
# 50%    8.290e+00  1.425e+01  1.118e+01  1.890e+01  1.043e+02  3.297e+01
# 75%    1.191e+01  1.910e+01  1.554e+01  3.720e+01  1.615e+02  6.876e+01
# max    2.069e+01  3.117e+01  2.530e+01  2.404e+02  2.990e+02  5.007e+02
#
#        croissance
# count   1.867e+07
# mean    3.710e+01
# std     3.066e+01
# min     0.000e+00
# 25%     1.090e+01
# 50%     2.812e+01
# 75%     5.997e+01
# max     1.424e+02

# %%
df[["ucs", "safran", "sol"]].corr()
# Out:
#           ucs  safran    sol
# ucs     1.000   0.937  0.085
# safran  0.937   1.000  0.032
# sol     0.085   0.032  1.000

# %% [markdown]
# #### Define the columns used in the paper

# %%
# sol as PCU ?
valuable_columns = ["sol", "annee", "decade", "Tmin", "Tmax", "Tmoy", "Rain", "RG", "im", "croissance"]
df = croissance_et_climat_decadaires[valuable_columns]

# %%
df.head()
# Out:
#       sol   annee  decade   Tmin    Tmax    Tmoy  Rain      RG       im  \
# 0  330343  1985.0     1.0 -2.289   3.178   0.444  12.3  28.912   43.573
# 1  330343  1985.0     2.0 -5.740  -0.410  -3.075  19.5  33.793  104.188
# 2  330343  1985.0     3.0  3.770   9.130   6.450  36.8  24.751   82.772
# 3  330343  1985.0     4.0  8.230  12.450  10.340  14.4  32.975   26.195
# 4  330343  1985.0     5.0 -1.380   2.520   0.570  25.3  48.912   88.562
#
#    croissance
# 0       0.032
# 1       0.000
# 2       0.046
# 3       0.075
# 4       0.015

# %%
df.shape
# Out:
# (18693829, 10)

# %%
(df.isna() | df.isnull()).sum()
# Out:
# sol                0
# annee          20262
# decade         20262
# Tmin          126008
# Tmax          126008
# Tmoy          126008
# Rain          126008
# RG            126008
# im            126008
# croissance     20262
# dtype: int64

# %%
df.groupby(["sol"]).count() # we could set the same number of lines for each sol
df.reset_index(inplace=True)

# %% [markdown]
# ### Mean 10 years per PUD

# %%
df_10y = df.groupby(["sol", "annee", "decade"]).sample(n=10, replace=True)
df_10y = df_10y.groupby(["sol", "annee", "decade"]).mean()
df = df_10y.reset_index()
#df.drop(["index"])

# %%
df.head()
# Out:
#       sol   annee  decade      index   Tmin    Tmax   Tmoy    Rain      RG  \
# 0  330343  1984.0     1.0  7.712e+06  4.435   8.814  6.624  26.467  30.134
# 1  330343  1984.0     2.0  1.564e+07  4.119   9.082  6.600  38.070  25.623
# 2  330343  1984.0     3.0  1.048e+07  3.068   8.189  5.628  49.450  41.328
# 3  330343  1984.0     4.0  1.252e+07  6.762  10.448  8.605  34.070  38.593
# 4  330343  1984.0     5.0  8.764e+06 -0.208   7.297  3.544   0.000  96.704
#
#         im  croissance
# 0   58.896       2.540
# 1   84.789       2.108
# 2  117.065       1.850
# 3   67.784       5.878
# 4    0.000       4.530

# %%
df.describe()
# Out:
#               sol      annee     decade      index       Tmin       Tmax  \
# count   26640.000  26640.000  26640.000  2.664e+04  26640.000  26640.000
# mean   331246.125   1998.500     19.000  9.437e+06      8.329     14.681
# std       965.872      8.656     10.677  3.882e+06      4.294      5.514
# min    330343.000   1984.000      1.000  1.007e+06     -6.924     -3.171
# 25%    330506.500   1991.000     10.000  6.811e+06      5.140     10.495
# 50%    330598.500   1998.500     19.000  9.609e+06      8.360     14.321
# 75%    332378.250   2006.000     28.000  1.199e+07     11.975     19.157
# max    332668.000   2013.000     37.000  1.842e+07     19.357     30.342
#
#             Tmoy       Rain         RG         im  croissance
# count  26640.000  26640.000  26640.000  26640.000   26640.000
# mean      11.505     25.198    108.491     46.676      36.207
# std        4.820     23.020     65.177     44.955      28.327
# min       -5.022      0.000      8.331      0.000       0.000
# 25%        7.943      7.508     47.339     12.482      11.952
# 50%       11.258     19.280    104.913     33.556      28.516
# 75%       15.591     36.620    160.671     67.159      56.631
# max       24.741    199.850    297.139    400.284     127.651

# %% [markdown]
# ### Preprocess and sort the dataframe

# %%
df["annee"] = df["annee"].astype("int64")
df["decade"] = df["decade"].astype("int64")
df = df.groupby(["sol", "annee"]) ######################### Why doesn't group ?
df.head()
# Out:
#           sol  annee  decade      index   Tmin    Tmax   Tmoy    Rain      RG  \
# 0      330343   1984       1  7.712e+06  4.435   8.814  6.624  26.467  30.134
# 1      330343   1984       2  1.564e+07  4.119   9.082  6.600  38.070  25.623
# 2      330343   1984       3  1.048e+07  3.068   8.189  5.628  49.450  41.328
# 3      330343   1984       4  1.252e+07  6.762  10.448  8.605  34.070  38.593
# 4      330343   1984       5  8.764e+06 -0.208   7.297  3.544   0.000  96.704
# ...       ...    ...     ...        ...    ...     ...    ...     ...     ...
# 26603  332668   2013       1  1.133e+07  6.500   8.561  7.531   7.850  16.456
# 26604  332668   2013       2  1.808e+07  2.560   6.310  4.435  24.360  26.611
# 26605  332668   2013       3  1.133e+07  3.060   8.050  5.555  58.650  37.469
# 26606  332668   2013       4  1.268e+07  5.204   8.933  7.069  46.460  37.943
# 26607  332668   2013       5  1.133e+07  3.156   9.017  6.086  32.200  62.940
#
#             im  croissance
# 0       58.896       2.540
# 1       84.789       2.108
# 2      117.065       1.850
# 3       67.784       5.878
# 4        0.000       4.530
# ...        ...         ...
# 26603   16.570      12.727
# 26604   62.441       9.061
# 26605  139.439       5.241
# 26606  101.517      17.004
# 26607   74.116      11.655
#
# [3600 rows x 11 columns]

# %%
df.describe(include= "all")
# Out:
#               sol      annee     decade       Tmin       Tmax       Tmoy  \
# count   26640.000  26640.000  26640.000  26640.000  26640.000  26640.000
# mean   331246.125   1998.500     19.000      8.329     14.684     11.506
# std       965.872      8.656     10.677      4.291      5.515      4.819
# min    330343.000   1984.000      1.000     -7.368     -3.699     -5.534
# 25%    330506.500   1991.000     10.000      5.142     10.491      7.929
# 50%    330598.500   1998.500     19.000      8.358     14.316     11.245
# 75%    332378.250   2006.000     28.000     11.966     19.142     15.580
# max    332668.000   2013.000     37.000     19.251     30.420     24.562
#
#             Rain         RG         im  croissance
# count  26640.000  26640.000  26640.000   26640.000
# mean      25.203    108.526     46.682      36.236
# std       22.988     65.215     44.911      28.367
# min        0.000      8.760      0.000       0.000
# 25%        7.500     47.316     12.585      12.000
# 50%       19.230    104.961     33.502      28.485
# 75%       36.352    160.713     67.252      57.000
# max      206.200    297.139    421.014     132.464

# %% [markdown]
# ## Analysis of annual valuations

# %%
df = valorisation_annuelle

# %%
valorisation_annuelle.head()
# Out:
#     ucs  safran     sol type_de_prairie  gestion   annee  valorisation     RU  \
# 0  1005    2245  330562             tp3       15  1985.0         4.964  97.42
# 1  1005    2245  330562             tp3       15  1986.0         8.173  97.42
# 2  1005    2245  330562             tp3       15  1987.0        12.666  97.42
# 3  1005    2245  330562             tp3       15  1989.0         5.825  97.42
# 4  1005    2245  330562             tp3       15  1990.0         7.212  97.42
#
#    cumul_croissance
# 0             8.757
# 1            14.620
# 2            16.287
# 3             9.063
# 4            11.758

# %%
valorisation_annuelle.describe()
# Out:
#               ucs      safran         sol     gestion       annee  \
# count  535406.000  535406.000  535406.000  535406.000  535406.000
# mean     1050.229    2509.312  330824.012      13.939    1998.691
# std       221.389     548.252     652.279       9.559       8.625
# min       640.000    1309.000  330343.000       1.000    1984.000
# 25%       875.000    2115.000  330556.000       5.000    1991.000
# 50%      1080.000    2493.000  330563.000      15.000    1999.000
# 75%      1218.000    2889.000  330638.000      22.000    2006.000
# max      1610.000    3886.000  332668.000      30.000    2013.000
#
#        valorisation          RU  cumul_croissance
# count    535406.000  535406.000        535406.000
# mean          9.799     102.657            13.771
# std           3.713      41.150             3.777
# min           0.000      21.139             0.754
# 25%           7.131      89.180            11.155
# 50%           9.824      97.420            13.813
# 75%          12.452     148.680            16.441
# max          23.039     351.240            26.845

# %%
print(valorisation_annuelle.shape)
print(valorisation_annuelle.columns)
print(valorisation_annuelle.info())
# Out:
# (535406, 9)
# Index(['ucs', 'safran', 'sol', 'type_de_prairie', 'gestion', 'annee',
#        'valorisation', 'RU', 'cumul_croissance'],
#       dtype='object')
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 535406 entries, 0 to 535405
# Data columns (total 9 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   ucs               535406 non-null  int32
#  1   safran            535406 non-null  int32
#  2   sol               535406 non-null  int32
#  3   type_de_prairie   535406 non-null  object
#  4   gestion           535406 non-null  int32
#  5   annee             535406 non-null  float64
#  6   valorisation      535406 non-null  float64
#  7   RU                535406 non-null  float64
#  8   cumul_croissance  535406 non-null  float64
# dtypes: float64(4), int32(4), object(1)
# memory usage: 28.6+ MB
# None

# %%
for column in valorisation_annuelle.columns:
    if column in croissance_et_climat_decadaires.columns:
        print(column)
# Out:
# ucs
# safran
# sol
# type_de_prairie
# gestion
# annee

# %%
valuable_columns = ["sol", "annee", "cumul_croissance"]
df = df[valuable_columns]

# %%
(df.isna() | df.isnull()).sum()
# Out:
# sol                 0
# annee               0
# cumul_croissance    0
# dtype: int64

# %%
df.groupby("annee").nunique()
# Out:
#         sol  cumul_croissance
# annee
# 1984.0   24              7786
# 1985.0   24             16089
# 1986.0   24             15765
# 1987.0   24             10789
# 1988.0   24             13187
# 1989.0   24             16097
# 1990.0   24             10595
# 1991.0   24             16558
# 1992.0   24             13431
# 1993.0   24             10739
# 1994.0   24             15895
# 1995.0   24             16477
# 1996.0   24              7831
# 1997.0   24             16260
# 1998.0   24             15778
# 1999.0   24             10777
# 2000.0   24             13367
# 2001.0   24             16454
# 2002.0   24             10391
# 2003.0   24             16420
# 2004.0   24             13361
# 2005.0   24             10899
# 2006.0   24             16058
# 2007.0   24             16484
# 2008.0   24              7664
# 2009.0   24             15980
# 2010.0   24             15869
# 2011.0   24             10934
# 2012.0   24             13395
# 2013.0   24             16327

# %% [markdown]
# ### Mean 10 years per PUD

# %%
df_10y = df.groupby(["sol", "annee"]).sample(n=10, replace=True)
df = df_10y.groupby(["sol", "annee"]).mean()
df.head()
# Out:
#                cumul_croissance
# sol    annee
# 330343 1984.0             7.237
#        1985.0             8.309
#        1986.0            13.034
#        1987.0            14.227
#        1988.0            13.353

# %% [markdown]
# ### Preprocess and sort the dataframe

# %%
df.reset_index()
df["annee"] = df["annee"].astype("int64")
df = df.sort_values(by=["sol", "annee"])
df.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\envs\machine-learning\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File ~\anaconda3\envs\machine-learning\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\envs\machine-learning\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'annee'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Input In [95], in <cell line: 2>()
#       1 df.reset_index()
# ----> 2 df["annee"] = df["annee"].astype("int64")
#       3 df = df.sort_values(by=["sol", "annee"])
#       4 df.head()
#
# File ~\anaconda3\envs\machine-learning\lib\site-packages\pandas\core\frame.py:3505, in DataFrame.__getitem__(self, key)
#    3503 if self.columns.nlevels > 1:
#    3504     return self._getitem_multilevel(key)
# -> 3505 indexer = self.columns.get_loc(key)
#    3506 if is_integer(indexer):
#    3507     indexer = [indexer]
#
# File ~\anaconda3\envs\machine-learning\lib\site-packages\pandas\core\indexes\base.py:3623, in Index.get_loc(self, key, method, tolerance)
#    3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
# -> 3623     raise KeyError(key) from err
#    3624 except TypeError:
#    3625     # If we have a listlike key, _check_indexing_error will raise
#    3626     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3627     #  the TypeError.
#    3628     self._check_indexing_error(key)
#
# KeyError: 'annee'

# %%
df.describe(include= "all")

# %% [markdown]
# ## Preprocessing

# %%
X = croissance_et_climat_decadaires.loc[:, ["annee","decade","Tmin","Tmax","Tmoy","Rain","RG","im"]].values.astype(float)
y = valorisation_annuelle.loc[:, ["cumul_croissance"]].values.astype(float)
