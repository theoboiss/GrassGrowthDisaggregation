# %% [markdown]
# # Exploratory Data Analysis

# %%
# Importing the libraries

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
# Define settings
import os

pd.set_option("display.precision", 3)
data_dir_path = os.getcwd() + '/dataverse_files/'

# %%
# Importing data
import pyreadr

croissance_et_climat_decadaires = pyreadr.read_r(data_dir_path + "croissance_et_climat_decadaires.rds" ).popitem()[1]
valorisation_annuelle = pyreadr.read_r(data_dir_path + "valorisation_annuelle.rds" ).popitem()[1]

# %% [markdown]
# ## Analysis of growths and decadal climates

# %%
df = croissance_et_climat_decadaires

# %%
df.head()
# Out:
#    ucs  safran     sol type_de_prairie  gestion   annee  decade   Tmin  \
# 0  789    2131  330343             tp3       20  1985.0     1.0 -2.289
# 1  789    2131  330343             tp3       20  1985.0     2.0 -5.740
# 2  789    2131  330343             tp3       20  1985.0     3.0  3.770
# 3  789    2131  330343             tp3       20  1985.0     4.0  8.230
# 4  789    2131  330343             tp3       20  1985.0     5.0 -1.380
#
#      Tmax    Tmoy  Rain      RG       im  croissance
# 0   3.178   0.444  12.3  28.912   43.573       0.032
# 1  -0.410  -3.075  19.5  33.793  104.188       0.000
# 2   9.130   6.450  36.8  24.751   82.772       0.046
# 3  12.450  10.340  14.4  32.975   26.195       0.075
# 4   2.520   0.570  25.3  48.912   88.562       0.015

# %%
print(df.shape)
print(df.columns)
print(df.info())
# Out:
# (18693829, 14)
# Index(['ucs', 'safran', 'sol', 'type_de_prairie', 'gestion', 'annee', 'decade',
#        'Tmin', 'Tmax', 'Tmoy', 'Rain', 'RG', 'im', 'croissance'],
#       dtype='object')
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18693829 entries, 0 to 18693828
# Data columns (total 14 columns):
#  #   Column           Dtype
# ---  ------           -----
#  0   ucs              int32
#  1   safran           int32
#  2   sol              int32
#  3   type_de_prairie  object
#  4   gestion          int32
#  5   annee            float64
#  6   decade           float64
#  7   Tmin             float64
#  8   Tmax             float64
#  9   Tmoy             float64
#  10  Rain             float64
#  11  RG               float64
#  12  im               float64
#  13  croissance       float64
# dtypes: float64(9), int32(4), object(1)
# memory usage: 1.7+ GB
# None

# %%
df.describe(include= "all")
# Out:
#               ucs     safran        sol type_de_prairie    gestion      annee  \
# count   1.869e+07  1.869e+07  1.869e+07        18693829  1.869e+07  1.867e+07
# unique        NaN        NaN        NaN               3        NaN        NaN
# top           NaN        NaN        NaN             tp4        NaN        NaN
# freq          NaN        NaN        NaN        10563388        NaN        NaN
# mean    1.054e+03  2.523e+03  3.308e+05             NaN  1.362e+01  1.999e+03
# std     2.229e+02  5.508e+02  6.531e+02             NaN  9.407e+00  8.626e+00
# min     6.400e+02  1.309e+03  3.303e+05             NaN  1.000e+00  1.984e+03
# 25%     8.880e+02  2.120e+03  3.306e+05             NaN  5.000e+00  1.991e+03
# 50%     1.080e+03  2.497e+03  3.306e+05             NaN  1.500e+01  1.999e+03
# 75%     1.222e+03  2.895e+03  3.306e+05             NaN  2.100e+01  2.006e+03
# max     1.610e+03  3.886e+03  3.327e+05             NaN  3.000e+01  2.013e+03
#
#            decade       Tmin       Tmax       Tmoy       Rain         RG  \
# count   1.867e+07  1.857e+07  1.857e+07  1.857e+07  1.857e+07  1.857e+07
# unique        NaN        NaN        NaN        NaN        NaN        NaN
# top           NaN        NaN        NaN        NaN        NaN        NaN
# freq          NaN        NaN        NaN        NaN        NaN        NaN
# mean    1.900e+01  8.249e+00  1.464e+01  1.145e+01  2.578e+01  1.085e+02
# std     1.068e+01  4.365e+00  5.607e+00  4.893e+00  2.499e+01  6.581e+01
# min     1.000e+00 -8.760e+00 -5.380e+00 -7.020e+00  0.000e+00  7.170e+00
# 25%     1.000e+01  5.040e+00  1.043e+01  7.855e+00  6.800e+00  4.684e+01
# 50%     1.900e+01  8.290e+00  1.425e+01  1.118e+01  1.890e+01  1.043e+02
# 75%     2.800e+01  1.191e+01  1.910e+01  1.554e+01  3.720e+01  1.615e+02
# max     3.700e+01  2.069e+01  3.117e+01  2.530e+01  2.404e+02  2.990e+02
#
#                im  croissance
# count   1.857e+07   1.867e+07
# unique        NaN         NaN
# top           NaN         NaN
# freq          NaN         NaN
# mean    4.798e+01   3.710e+01
# std     4.897e+01   3.066e+01
# min     0.000e+00   0.000e+00
# 25%     1.144e+01   1.090e+01
# 50%     3.297e+01   2.812e+01
# 75%     6.876e+01   5.997e+01
# max     5.007e+02   1.424e+02

# %%
df[["ucs", "safran", "sol"]].corr()
# Out:
#           ucs  safran    sol
# ucs     1.000   0.937  0.085
# safran  0.937   1.000  0.032
# sol     0.085   0.032  1.000

# %% [markdown]
# ### Feature extraction

# %% [markdown]
# Pedo-Climatic Units (PCU), result from the crossing of the climatic information (SAFRAN grid point) and soil information (UCS soil mapping units).

# %%
df_unique_pcu = df[["ucs", "safran"]].drop_duplicates(subset= ['ucs', 'safran'])
df_unique_pcu['pcu'] = df_unique_pcu.reset_index().index

df = pd.merge(df, df_unique_pcu, on= ['ucs','safran'])
df.insert(0, "pcu", df.pop('pcu'))
df.head()
# Out:
#    pcu  ucs  safran     sol type_de_prairie  gestion   annee  decade   Tmin  \
# 0    0  789    2131  330343             tp3       20  1985.0     1.0 -2.289
# 1    0  789    2131  330343             tp3       20  1985.0     2.0 -5.740
# 2    0  789    2131  330343             tp3       20  1985.0     3.0  3.770
# 3    0  789    2131  330343             tp3       20  1985.0     4.0  8.230
# 4    0  789    2131  330343             tp3       20  1985.0     5.0 -1.380
#
#      Tmax    Tmoy  Rain      RG       im  croissance
# 0   3.178   0.444  12.3  28.912   43.573       0.032
# 1  -0.410  -3.075  19.5  33.793  104.188       0.000
# 2   9.130   6.450  36.8  24.751   82.772       0.046
# 3  12.450  10.340  14.4  32.975   26.195       0.075
# 4   2.520   0.570  25.3  48.912   88.562       0.015

# %%
df[["ucs", "safran", "pcu", "sol"]].corr()
# Out:
#           ucs  safran    pcu    sol
# ucs     1.000   0.937  0.432  0.085
# safran  0.937   1.000  0.444  0.032
# pcu     0.432   0.444  1.000 -0.085
# sol     0.085   0.032 -0.085  1.000

# %%
df_unique_pcu = df[['pcu', 'sol', 'type_de_prairie', 'gestion']].drop_duplicates(subset= ['pcu', 'sol', 'type_de_prairie', 'gestion'])
df_unique_pcu['id'] = df_unique_pcu.reset_index().index

df = pd.merge(df, df_unique_pcu, on= ['pcu', 'sol', 'type_de_prairie', 'gestion'])
df.insert(0, "id", df.pop('id'))
df.head()
# Out:
#    id  pcu  ucs  safran     sol type_de_prairie  gestion   annee  decade  \
# 0   0    0  789    2131  330343             tp3       20  1985.0     1.0
# 1   0    0  789    2131  330343             tp3       20  1985.0     2.0
# 2   0    0  789    2131  330343             tp3       20  1985.0     3.0
# 3   0    0  789    2131  330343             tp3       20  1985.0     4.0
# 4   0    0  789    2131  330343             tp3       20  1985.0     5.0
#
#     Tmin    Tmax    Tmoy  Rain      RG       im  croissance
# 0 -2.289   3.178   0.444  12.3  28.912   43.573       0.032
# 1 -5.740  -0.410  -3.075  19.5  33.793  104.188       0.000
# 2  3.770   9.130   6.450  36.8  24.751   82.772       0.046
# 3  8.230  12.450  10.340  14.4  32.975   26.195       0.075
# 4 -1.380   2.520   0.570  25.3  48.912   88.562       0.015

# %%
df.drop_duplicates("id")
# Out:
#              id   pcu  ucs  safran     sol type_de_prairie  gestion   annee  \
# 0             0     0  789    2131  330343             tp3       20  1985.0
# 741           1     0  789    2131  330343             tp3       21  1985.0
# 1482          2     0  789    2131  330343             tp3       23  1985.0
# 2223          3     0  789    2131  330343             tp3        3  1985.0
# 2964          4     0  789    2131  330343             tp3        7  1985.0
# ...         ...   ...  ...     ...     ...             ...      ...     ...
# 18688274  20257  1240  998    2511  330563             tp4       16  1984.0
# 18689385  20258  1240  998    2511  330563             tp4       18  1984.0
# 18690496  20259  1240  998    2511  330563             tp4       21  1984.0
# 18691607  20260  1240  998    2511  330563             tp4        3  1984.0
# 18692718  20261  1240  998    2511  330563             tp4        7  1984.0
#
#           decade   Tmin   Tmax   Tmoy  Rain      RG      im  croissance
# 0            1.0 -2.289  3.178  0.444  12.3  28.912  43.573       0.032
# 741          1.0 -2.289  3.178  0.444  12.3  28.912  43.573       0.032
# 1482         1.0 -2.289  3.178  0.444  12.3  28.912  43.573       0.032
# 2223         1.0 -2.289  3.178  0.444  12.3  28.912  43.573       0.032
# 2964         1.0 -2.289  3.178  0.444  12.3  28.912  43.573       0.032
# ...          ...    ...    ...    ...   ...     ...     ...         ...
# 18688274     1.0  3.000  7.756  5.378  34.0  33.100  81.806       1.337
# 18689385     1.0  3.000  7.756  5.378  34.0  33.100  81.806       1.337
# 18690496     1.0  3.000  7.756  5.378  34.0  33.100  81.806       1.337
# 18691607     1.0  3.000  7.756  5.378  34.0  33.100  81.806       1.337
# 18692718     1.0  3.000  7.756  5.378  34.0  33.100  81.806       1.337
#
# [20262 rows x 16 columns]

# %%
(df.groupby(["id", "annee"]).count()["decade"] == 37).all()
# Out:
# True

# %% [markdown]
# There is no more than one group of consecutive decades per year and per tuple (UCS, SAFRAN, SOL, prairie, gestion).

# %%
(df.groupby(["id", "annee", "decade"]).count().max() == 1).all()
# Out:
# True

# %% [markdown]
# Moreover, there is only one entry per year and per decade for a fixed tuple (UCS, SAFRAN, SOL, prairie, gestion).

# %%
df.groupby(["id", "decade"]).count()[["annee"]].describe().loc["min":"max"]
# Out:
#      annee
# min   15.0
# 25%   20.0
# 50%   22.0
# 75%   30.0
# max   30.0

# %% [markdown]
# Finally, only the year will change over the whole simulated period, i.e. 30 years, for each decade and for any tuple (UCS, SAFRAN, SOL, prairie, gestion).

# %% [markdown]
# Therefore, all groups of decades have the same values for the tuple (UCS, SAFRAN, SOL, prairie, gestion) and only the year will change (over the whole simulated period, ie 30 years).

# %% [markdown]
# So (UCS, SAFRAN, SOL, prairie, gestion) is the identifier.

# %% [markdown]
# ### Feature selection

# %% [markdown]
# "type_de_prairie" is not used as input of the model and the features we created before simply add more understanding to the data and does not help the model. Making the model learn many inputs, even without knowing these features will allow it to generalise.

# %%
valuable_columns = ["ucs", "safran", "sol", "gestion", "annee", "decade", "Tmin", "Tmax", "Tmoy", "Rain", "RG", "im", "croissance"]
df = df[valuable_columns]
df.head()
# Out:
#    ucs  safran     sol  gestion   annee  decade   Tmin    Tmax    Tmoy  Rain  \
# 0  789    2131  330343       20  1985.0     1.0 -2.289   3.178   0.444  12.3
# 1  789    2131  330343       20  1985.0     2.0 -5.740  -0.410  -3.075  19.5
# 2  789    2131  330343       20  1985.0     3.0  3.770   9.130   6.450  36.8
# 3  789    2131  330343       20  1985.0     4.0  8.230  12.450  10.340  14.4
# 4  789    2131  330343       20  1985.0     5.0 -1.380   2.520   0.570  25.3
#
#        RG       im  croissance
# 0  28.912   43.573       0.032
# 1  33.793  104.188       0.000
# 2  24.751   82.772       0.046
# 3  32.975   26.195       0.075
# 4  48.912   88.562       0.015

# %%
(df.isna() | df.isnull()).sum()
# Out:
# ucs                0
# safran             0
# sol                0
# gestion            0
# annee          20262
# decade         20262
# Tmin          126008
# Tmax          126008
# Tmoy          126008
# Rain          126008
# RG            126008
# im            126008
# croissance     20262
# dtype: int64

# %%
df.dropna(inplace= True)

# %%
(df.isna() | df.isnull()).sum()
# Out:
# ucs           0
# safran        0
# sol           0
# gestion       0
# annee         0
# decade        0
# Tmin          0
# Tmax          0
# Tmoy          0
# Rain          0
# RG            0
# im            0
# croissance    0
# dtype: int64

# %% [markdown]
# Now that we have removed the NaN and Null values, we need to check whether we have any missing decades among the years. We can do it by checking that the numbers of decades per (year,pcu) pairs are multiples of 37

# %%
df.describe()
# Out:
#              ucs     safran        sol    gestion      annee     decade  \
# count  1.857e+07  1.857e+07  1.857e+07  1.857e+07  1.857e+07  1.857e+07
# mean   1.054e+03  2.523e+03  3.308e+05  1.362e+01  1.999e+03  1.900e+01
# std    2.226e+02  5.498e+02  6.528e+02  9.412e+00  8.626e+00  1.068e+01
# min    6.400e+02  1.309e+03  3.303e+05  1.000e+00  1.984e+03  1.000e+00
# 25%    8.880e+02  2.120e+03  3.306e+05  5.000e+00  1.991e+03  1.000e+01
# 50%    1.080e+03  2.497e+03  3.306e+05  1.500e+01  1.999e+03  1.900e+01
# 75%    1.222e+03  2.895e+03  3.306e+05  2.100e+01  2.006e+03  2.800e+01
# max    1.610e+03  3.886e+03  3.327e+05  3.000e+01  2.013e+03  3.700e+01
#
#             Tmin       Tmax       Tmoy       Rain         RG         im  \
# count  1.857e+07  1.857e+07  1.857e+07  1.857e+07  1.857e+07  1.857e+07
# mean   8.249e+00  1.464e+01  1.145e+01  2.578e+01  1.085e+02  4.798e+01
# std    4.365e+00  5.607e+00  4.893e+00  2.499e+01  6.581e+01  4.897e+01
# min   -8.760e+00 -5.380e+00 -7.020e+00  0.000e+00  7.170e+00  0.000e+00
# 25%    5.040e+00  1.043e+01  7.855e+00  6.800e+00  4.684e+01  1.144e+01
# 50%    8.290e+00  1.425e+01  1.118e+01  1.890e+01  1.043e+02  3.297e+01
# 75%    1.191e+01  1.910e+01  1.554e+01  3.720e+01  1.615e+02  6.876e+01
# max    2.069e+01  3.117e+01  2.530e+01  2.404e+02  2.990e+02  5.007e+02
#
#        croissance
# count   1.857e+07
# mean    3.710e+01
# std     3.066e+01
# min     0.000e+00
# 25%     1.091e+01
# 50%     2.813e+01
# 75%     5.997e+01
# max     1.424e+02

# %% [markdown]
# ### Correct the dataframe

# %%
df["annee"] = df["annee"].astype("int64")
df["decade"] = df["decade"].astype("int64")

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 18567821 entries, 0 to 18693827
# Data columns (total 13 columns):
#  #   Column      Dtype
# ---  ------      -----
#  0   ucs         int32
#  1   safran      int32
#  2   sol         int32
#  3   gestion     int32
#  4   annee       int64
#  5   decade      int64
#  6   Tmin        float64
#  7   Tmax        float64
#  8   Tmoy        float64
#  9   Rain        float64
#  10  RG          float64
#  11  im          float64
#  12  croissance  float64
# dtypes: float64(7), int32(4), int64(2)
# memory usage: 1.7 GB
# None

# %%
croissance_et_climat_decadaires_preprocessed = df

# %% [markdown]
# ## Feature selection of annual valuations

# %%
df = valorisation_annuelle

# %%
df.head()

# %%
df.shape

# %%
valuable_columns = ["sol", "annee", "cumul_croissance"]
df = valorisation_annuelle[valuable_columns]

# %%
(df.isna() | df.isnull()).sum()

# %% [markdown]
# ### Reshape the dataframe

# %%
df = df.reset_index(drop=True)
df[["annee"]] = df[["annee"]].astype("int64")

# %%
df.head()

# %%
df.describe()

# %%
valorisation_annuelle_preprocessed = df

# %% [markdown]
# ## Concatenation

# %%
X = croissance_et_climat_decadaires_preprocessed.merge(valorisation_annuelle_preprocessed, how='right', on=["sol", "annee"])
#[
#    croissance_et_climat_decadaires_preprocessed.loc[:, ["sol", "annee", "decade", "Tmin", "Tmax", "Tmoy", "Rain", "RG", "im", "croissance"]],
#    valorisation_annuelle_preprocessed.loc[:, ["sol", "annee", "cumul_croissance"]]
#    ]
#y = df.loc[:, ["cumul_croissance"]].values.astype(float)
X

# %%
X.describe()
